# %% [markdown]
# <a href="https://colab.research.google.com/github/prkalva10/Collab/blob/main/Testes_com_dados_Mega_Sena.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
import numpy as np
import pandas as pd

# %%
print("Olá mundão")
# Out:
# Olá mundão

# %%
df = pd.read_csv("/content/sorteios.csv")

# %%
df.head()
# Out:
#    Id  Concurso Data Sorteio  1ª Dezena  2ª Dezena  3ª Dezena  4ª Dezena  \
# 0   1         1   11/03/1996         41          5          4         52
# 1   2         2   18/03/1996          9         39         37         49
# 2   3         3   25/03/1996         36         30         10         11
# 3   4         3   25/03/1996         36         30         10         11
# 4   5         4   01/04/1996          6         59         42         27
#
#    5ª Dezena  6ª Dezena Arrecadacao_Total  ...   Rateio_Sena Ganhadores_Quina  \
# 0         30         33              0,00  ...          0,00               17
# 1         43         41              0,00  ...  2.307.162,23               65
# 2         29         47              0,00  ...    391.192,51               62
# 3         29         47              0,00  ...    391.192,51               62
# 4          1          5              0,00  ...          0,00               39
#
# ...

# %%
nomes = df["Data Sorteio"]
nomes
# Out:
# 0       11/03/1996
# 1       18/03/1996
# 2       25/03/1996
# 3       25/03/1996
# 4       01/04/1996
#            ...
# 2273    11/07/2018
# 2274    14/07/2018
# 2275    18/07/2018
# 2276    21/07/2018
# 2277    25/07/2018
# Name: Data Sorteio, Length: 2278, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2278 entries, 0 to 2277
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        2278 non-null   int64
#  1   Concurso                  2278 non-null   int64
#  2   Data Sorteio              2278 non-null   object
#  3   1ª Dezena                 2278 non-null   int64
#  4   2ª Dezena                 2278 non-null   int64
#  5   3ª Dezena                 2278 non-null   int64
#  6   4ª Dezena                 2278 non-null   int64
#  7   5ª Dezena                 2278 non-null   int64
#  8   6ª Dezena                 2278 non-null   int64
#  9   Arrecadacao_Total         2278 non-null   object
#  10  Ganhadores_Sena           2278 non-null   int64
#  11  Cidade                    392 non-null    object
#  12  UF                        678 non-null    object
#  13  Rateio_Sena               2278 non-null   object
# ...

# %%
df.describe()
# Out:
#                 Id     Concurso    1ª Dezena    2ª Dezena    3ª Dezena  \
# count  2278.000000  2278.000000  2278.000000  2278.000000  2278.000000
# mean   1139.500000  1046.037752    30.441176    29.809482    30.546971
# std     657.746278   595.929308    17.439520    17.360566    17.518250
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%     570.250000   529.000000    15.000000    15.000000    15.000000
# 50%    1139.500000  1056.500000    31.000000    30.000000    30.000000
# 75%    1708.750000  1560.000000    46.000000    45.000000    46.000000
# max    2278.000000  2062.000000    60.000000    60.000000    60.000000
#
#          4ª Dezena    5ª Dezena    6ª Dezena  Ganhadores_Sena  \
# count  2278.000000  2278.000000  2278.000000      2278.000000
# mean     30.689640    30.054434    29.757682         0.774802
# std      17.225998    17.236672    17.404741         2.127623
# min       1.000000     1.000000     1.000000         0.000000
# ...

# %%
precos = [100,250,89,430,175]

# %%
print(precos)
# Out:
# [100, 250, 89, 430, 175]

# %%
precos_com_iva = []

# %%
precos_com_iva = [p * 1.10 for p in precos]

# %%
precos_com_iva
# Out:
# [110.00000000000001, 275.0, 97.9, 473.00000000000006, 192.50000000000003]

# %%
precos_com_iva = [p for p in precos if p > 150]

# %%
precos_com_iva
# Out:
# [250, 430, 175]

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("olistbr/brazilian-ecommerce")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'brazilian-ecommerce' dataset.
# Path to dataset files: /kaggle/input/brazilian-ecommerce

# %%
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/brazilian-ecommerce

# %%
df_orders_items = pd.read_csv(path + "/olist_order_items_dataset.csv")
df_orders_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
df_products = pd.read_csv(path + "/olist_products_dataset.csv")
df_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
df_categories = pd.read_csv(path + "/product_category_name_translation.csv")
df_categories.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
df_categories.tail()
# Out:
#             product_category_name product_category_name_english
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services

# %%
import pandas as pd

# %%
df_orders_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
vendas_vendedores = df_orders_items.groupby("seller_id")["price"].sum()

# %%
vendas_vendedores
# Out:
# seller_id
# 0015a82c2db000af6aaaf3ae2ecb0532     2685.00
# 001cca7ae9ae17fb1caed9dfb1094831    25080.03
# 001e6ad469a905060d959994f1b41e4f      250.00
# 002100f778ceb8431b7a1020ff7ab48f     1234.50
# 003554e2dce176b5555353e4f3555ac8      120.00
#                                       ...
# ffcfefa19b08742c5d315f2791395ee5       69.90
# ffdd9f82b9a447f6f8d4b91554cc7dd3     2101.20
# ffeee66ac5d5a62fe688b9d26f83f534     1839.86
# fffd5413c0700ac820c7069d66d98c89     9062.30
# ffff564a4f9085cd26170f4732393726     1426.30
# Name: price, Length: 3095, dtype: float64

# %%
rankings_vendedores = vendas_vendedores.sort_values(ascending=False)

# %%
rankings_vendedores
# Out:
# seller_id
# 4869f7a5dfa277a7dca6462dcf3b52b2    229472.63
# 53243585a1d6dc2643021fd1853d8905    222776.05
# 4a3ca9315b744ce9f8e9374361493884    200472.92
# fa1c13f2614d7b5c4749cbc52fecda94    194042.03
# 7c67e1448b00f6e969d365cea6b010ab    187923.89
#                                       ...
# 34aefe746cd81b7f3b23253ea28bef39         8.00
# 702835e4b785b67a084280efca355756         7.60
# 1fa2d3def6adfa70e58c276bb64fe5bb         6.90
# 77128dec4bec4878c37ab7d6169d6f26         6.50
# cf6f6bc4df3999b9c6440f124fb2f687         3.50
# Name: price, Length: 3095, dtype: float64

# %%
rankings_vendedores.head(10)
# Out:
# seller_id
# 4869f7a5dfa277a7dca6462dcf3b52b2    229472.63
# 53243585a1d6dc2643021fd1853d8905    222776.05
# 4a3ca9315b744ce9f8e9374361493884    200472.92
# fa1c13f2614d7b5c4749cbc52fecda94    194042.03
# 7c67e1448b00f6e969d365cea6b010ab    187923.89
# 7e93a43ef30c4f03f38b393420bc753a    176431.87
# da8622b14eb17ae2831f4ac5b9dab84a    160236.57
# 7a67c85e85bb2ce8582c35f2203ad736    141745.53
# 1025f0e2d44d7041d6cf58b6550e0bfa    138968.55
# 955fee9216a65b617aa5c0531780ce60    135171.70
# Name: price, dtype: float64

# %%
pip install nbstripout
