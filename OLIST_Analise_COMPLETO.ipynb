# %% [markdown]
# <a href="https://colab.research.google.com/github/prkalva10/Collab/blob/main/OLIST_Analise_COMPLETO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Análise de Dados - Aula final**
